# %%
from pathlib import Path

import pandas as pd

import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn3
import seaborn as sns

# %%
plt.rcParams["figure.figsize"] = (8, 6)

# %%
data_dir = Path("../data")
nb_dir = data_dir / "coverage"

# %%
# Load Scopus coverage
scopus = pd.read_csv(nb_dir / "scopus/CiteScore_2019.csv", index_col="Scopus Source ID")

# Load Web of Science coverage
dfs = []
for file in (nb_dir / "wos").glob("wos-core*.csv"):
    dfs.append(pd.read_csv(file))
wos = pd.concat(dfs)

# Load Scite data
scite = pd.read_csv(nb_dir / "scite/touched-issns.csv")

# %%
scopus_issns = set(scopus["Print ISSN"].tolist() + scopus["E-ISSN"].tolist())
wos_issns = set(wos.ISSN.str.replace("-", "").tolist() + wos.eISSN.str.replace("-", "").tolist())
scite_issns = set(scite.issn.str.replace("-", ""))

# %%
venn3(subsets=[scopus_issns, wos_issns, scite_issns], set_labels=["scopus", "wos", "scite"])
plt.title("Overlap of ISSNs");

# %%
scopus["Publisher"].value_counts()
# Out:
# Springer Nature                                          6325
# Elsevier                                                 5901
# Taylor & Francis                                         5315
# Wiley-Blackwell                                          3393
# SAGE                                                     1841
#                                                          ...
# Ecole Nationale du Genie Rural des Eaux et des Forets       1
# Societas Philosophia Classica                               1
# Research and publications office, Jimma University          1
# Peritoneal Dialysis Bulletin                                1
# Massimo Morgante                                            1
# Name: Publisher, Length: 6892, dtype: int64

# %%
wos["Publisher name"].value_counts()
# Out:
# WILEY                                          4919
# SPRINGER                                       3561
# ROUTLEDGE JOURNALS, TAYLOR & FRANCIS LTD       2577
# ELSEVIER                                       2373
# TAYLOR & FRANCIS LTD                           1831
#                                                ...
# EGYPTIAN GEOLOGICAL SURVEY MINING AUTHORITY       1
# CANADIAN SOC CONTINENTAL PHILOSOPHY               1
# EDITORA FORUM                                     1
# INST GEOLOGICO MINERO METALURGICO-INGEMMET        1
# FUKUI NATURE CONSERVATION CENTER                  1
# Name: Publisher name, Length: 7955, dtype: int64

# %%
scopus[scopus.Publisher=="Cambridge University Press"].drop_duplicates(subset=["Print ISSN", "E-ISSN"])
# Out:
#                                                      Title  Citation Count  \
# Scopus Source ID
# 12128              Behavioural and Cognitive Psychotherapy             652
# 21100455134                              Queensland Review              10
# 23953             Rural History: Economy, Society, Culture              32
# 12256                                Cambridge Law Journal             108
# 21100899217                        Wireless Power Transfer             121
# ...                                                    ...             ...
# 19900191623                                     AJS Review              25
# 23144                                  Language in Society             330
# 25301                           Bulletin of Symbolic Logic              67
# 12100155921                      Social Policy and Society             506
# 21100897230                      Studies in Church History               7
#
#                   Scholarly Output  Percent Cited  CiteScore   SNIP    SJR  \
# Scopus Source ID
# 12128                          226           70.8        2.9  0.981  0.805
# 21100455134                     79           10.1        0.1  0.013  0.105
# 23953                           47           44.7        0.7  0.888  0.135
# 12256                          116           41.4        0.9  1.347  0.412
# 21100899217                     46           71.7        2.6  0.406  0.252
# ...                            ...            ...        ...    ...    ...
# 19900191623                     51           27.5        0.5  0.716  0.203
# 23144                          108           65.7        3.1  2.208  1.027
# 25301                           51           41.2        1.3  1.796  0.361
# 12100155921                    177           75.1        2.9  1.293  0.762
# 21100897230                     56            7.1        0.1  0.290  0.124
#
#                   Scopus ASJC Code (Sub-subject Area)  \
# Scopus Source ID
# 12128                                          3203.0
# 21100455134                                    3312.0
# 23953                                          3305.0
# 12256                                          3308.0
# 21100899217                                    2102.0
# ...                                               ...
# 19900191623                                    1212.0
# 23144                                          1203.0
# 25301                                          1211.0
# 12100155921                                    3320.0
# 21100897230                                    1212.0
#
#                                         Scopus Sub-Subject Area  Percentile  \
# Scopus Source ID
# 12128                                       Clinical Psychology        68.0
# 21100455134                     Sociology and Political Science        12.0
# 23953                       Geography, Planning and Development        31.0
# 12256                                                       Law        53.0
# 21100899217             Energy Engineering and Power Technology        57.0
# ...                                                         ...         ...
# 19900191623                                   Religious Studies        78.0
# 23144                                  Language and Linguistics        93.0
# 25301                                                Philosophy        84.0
# 12100155921       Political Science and International Relations        86.0
# 21100897230                                   Religious Studies        29.0
#
#                     RANK  Rank Out Of                   Publisher Type  \
# Scopus Source ID
# 12128               88.0        275.0  Cambridge University Press    j
# 21100455134       1090.0       1243.0  Cambridge University Press    j
# 23953              467.0        679.0  Cambridge University Press    j
# 12256              321.0        685.0  Cambridge University Press    j
# 21100899217         92.0        216.0  Cambridge University Press    j
# ...                  ...          ...                         ...  ...
# 19900191623        106.0        492.0  Cambridge University Press    j
# 23144               51.0        830.0  Cambridge University Press    j
# 25301               92.0        606.0  Cambridge University Press    j
# 12100155921         74.0        529.0  Cambridge University Press    j
# 21100897230        345.0        492.0  Cambridge University Press    k
#
#                  Open Access  Quartile  Top 10% (CiteScore Percentile)  \
# Scopus Source ID
# 12128                     NO       2.0                               0
# 21100455134               NO       4.0                               0
# 23953                     NO       3.0                               0
# 12256                     NO       2.0                               0
# 21100899217               NO       2.0                               0
# ...                      ...       ...                             ...
# 19900191623               NO       1.0                               0
# 23144                     NO       1.0                               1
# 25301                     NO       1.0                               0
# 12100155921               NO       1.0                               0
# 21100897230               NO       3.0                               0
#
#                                          URL Scopus Source ID Print ISSN  \
# Scopus Source ID
# 12128                   https://www.scopus.com/sourceid/12128   13524658
# 21100455134       https://www.scopus.com/sourceid/21100455134   13218166
# 23953                   https://www.scopus.com/sourceid/23953    9567933
# 12256                   https://www.scopus.com/sourceid/12256      81973
# 21100899217       https://www.scopus.com/sourceid/21100899217        NaN
# ...                                                       ...        ...
# 19900191623       https://www.scopus.com/sourceid/19900191623    3640094
# 23144                   https://www.scopus.com/sourceid/23144     474045
# 25301                   https://www.scopus.com/sourceid/25301   10798986
# 12100155921       https://www.scopus.com/sourceid/12100155921   14747464
# 21100897230       https://www.scopus.com/sourceid/21100897230    4242084
#
#                     E-ISSN
# Scopus Source ID
# 12128             14691833
# 21100455134       20497792
# 23953             14740656
# 12256             14692139
# 21100899217       20528418
# ...                    ...
# 19900191623       14754541
# 23144             14698013
# 25301                  NaN
# 12100155921       14753073
# 21100897230       20590644
#
# [363 rows x 20 columns]

# %%
wos[wos["Publisher name"] == "CAMBRIDGE UNIV PRESS"]["Journal title"].nunique()
# Out:
# 355
